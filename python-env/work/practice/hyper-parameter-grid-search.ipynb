# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
dataset = load_breast_cancer()
t = dataset.target
x = dataset.data
x_train_val, x_test, t_train_val, t_test = train_test_split(x, t, test_size=0.2, random_state=1)

# %%
from sklearn.model_selection import GridSearchCV
# estimator, 学習に使用するモデル
# param_grid, ハイパーパラメータを探索する範囲
# CV, K-分割交差検証のKの値

# %%
estimator = DecisionTreeClassifier(random_state=0)

# %%
param_grid = [{
    'max_depth': [3, 20, 50], 
    'min_samples_split': [3, 20, 50]
}]

# %%
cv = 5

# %%
tuned_model = GridSearchCV(estimator=estimator,
                           param_grid=param_grid,
                           cv=cv,
                           return_train_score=False)

# %%
tuned_model.fit(x_train_val, t_train_val)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=0),
#              param_grid=[{'max_depth': [3, 20, 50],
#                           'min_samples_split': [3, 20, 50]}])

# %%
pd.DataFrame(tuned_model.cv_results_).T
# Out:
#                                                                 0  \
# mean_fit_time                                            0.002858
# std_fit_time                                             0.000117
# mean_score_time                                          0.000295
# std_score_time                                           0.000037
# param_max_depth                                                 3
# param_min_samples_split                                         3
# params                   {'max_depth': 3, 'min_samples_split': 3}
# split0_test_score                                        0.923077
# split1_test_score                                        0.901099
# split2_test_score                                        0.934066
# split3_test_score                                        0.945055
# split4_test_score                                        0.901099
# mean_test_score                                          0.920879
# std_test_score                                           0.017582
# rank_test_score                                                 5
#
#                                                                  1  \
# mean_fit_time                                              0.00271
# std_fit_time                                              0.000022
# mean_score_time                                           0.000277
# std_score_time                                            0.000043
# param_max_depth                                                  3
# param_min_samples_split                                         20
# params                   {'max_depth': 3, 'min_samples_split': 20}
# split0_test_score                                         0.912088
# split1_test_score                                         0.901099
# split2_test_score                                         0.934066
# split3_test_score                                         0.934066
# split4_test_score                                         0.901099
# mean_test_score                                           0.916484
# std_test_score                                            0.014906
# rank_test_score                                                  9
#
#                                                                  2  \
# mean_fit_time                                             0.002689
# std_fit_time                                              0.000015
# mean_score_time                                            0.00026
# std_score_time                                             0.00001
# param_max_depth                                                  3
# param_min_samples_split                                         50
# params                   {'max_depth': 3, 'min_samples_split': 50}
# split0_test_score                                         0.912088
# split1_test_score                                         0.901099
# split2_test_score                                         0.945055
# split3_test_score                                         0.934066
# split4_test_score                                         0.901099
# mean_test_score                                           0.918681
# std_test_score                                            0.017855
# rank_test_score                                                  6
#
#                                                                  3  \
# mean_fit_time                                             0.003253
# std_fit_time                                              0.000133
# mean_score_time                                           0.000263
# std_score_time                                            0.000016
# param_max_depth                                                 20
# param_min_samples_split                                          3
# params                   {'max_depth': 20, 'min_samples_split': 3}
# split0_test_score                                         0.956044
# split1_test_score                                         0.912088
# split2_test_score                                         0.923077
# split3_test_score                                         0.967033
# split4_test_score                                         0.956044
# mean_test_score                                           0.942857
# std_test_score                                            0.021308
# rank_test_score                                                  1
#
#                                                                   4  \
# mean_fit_time                                              0.003177
# std_fit_time                                               0.000166
# mean_score_time                                            0.000264
# std_score_time                                             0.000015
# param_max_depth                                                  20
# param_min_samples_split                                          20
# params                   {'max_depth': 20, 'min_samples_split': 20}
# split0_test_score                                          0.912088
# split1_test_score                                          0.901099
# split2_test_score                                          0.934066
# split3_test_score                                          0.945055
# split4_test_score                                          0.934066
# mean_test_score                                            0.925275
# std_test_score                                              0.01615
# rank_test_score                                                   3
#
#                                                                   5  \
# mean_fit_time                                              0.003157
# std_fit_time                                               0.000166
# mean_score_time                                            0.000258
# std_score_time                                             0.000006
# param_max_depth                                                  20
# param_min_samples_split                                          50
# params                   {'max_depth': 20, 'min_samples_split': 50}
# split0_test_score                                          0.912088
# split1_test_score                                          0.901099
# split2_test_score                                          0.945055
# split3_test_score                                          0.934066
# split4_test_score                                          0.901099
# mean_test_score                                            0.918681
# std_test_score                                             0.017855
# rank_test_score                                                   6
#
#                                                                  6  \
# mean_fit_time                                             0.003263
# std_fit_time                                              0.000156
# mean_score_time                                           0.000295
# std_score_time                                            0.000048
# param_max_depth                                                 50
# param_min_samples_split                                          3
# params                   {'max_depth': 50, 'min_samples_split': 3}
# split0_test_score                                         0.956044
# split1_test_score                                         0.912088
# split2_test_score                                         0.923077
# split3_test_score                                         0.967033
# split4_test_score                                         0.956044
# mean_test_score                                           0.942857
# std_test_score                                            0.021308
# rank_test_score                                                  1
#
#                                                                   7  \
# mean_fit_time                                              0.003183
# std_fit_time                                               0.000175
# mean_score_time                                            0.000259
# std_score_time                                             0.000006
# param_max_depth                                                  50
# param_min_samples_split                                          20
# params                   {'max_depth': 50, 'min_samples_split': 20}
# split0_test_score                                          0.912088
# split1_test_score                                          0.901099
# split2_test_score                                          0.934066
# split3_test_score                                          0.945055
# split4_test_score                                          0.934066
# mean_test_score                                            0.925275
# std_test_score                                              0.01615
# rank_test_score                                                   3
#
#                                                                   8
# mean_fit_time                                               0.00314
# std_fit_time                                               0.000182
# mean_score_time                                            0.000262
# std_score_time                                             0.000014
# param_max_depth                                                  50
# param_min_samples_split                                          50
# params                   {'max_depth': 50, 'min_samples_split': 50}
# split0_test_score                                          0.912088
# split1_test_score                                          0.901099
# split2_test_score                                          0.945055
# split3_test_score                                          0.934066
# split4_test_score                                          0.901099
# mean_test_score                                            0.918681
# std_test_score                                             0.017855
# rank_test_score                                                   6

# %%
param_grid = [{
    'max_depth': [5, 10, 15], 
    'min_samples_split': [10, 12, 15]
}]

# %%
tuned_model = GridSearchCV(estimator=estimator,
                           param_grid=param_grid,
                           cv=cv,
                           return_train_score=False)

# %%
tuned_model.fit(x_train_val, t_train_val)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=0),
#              param_grid=[{'max_depth': [5, 10, 15],
#                           'min_samples_split': [10, 12, 15]}])

# %%
pd.DataFrame(tuned_model.cv_results_).T
# Out:
#                                                                  0  \
# mean_fit_time                                             0.003706
# std_fit_time                                              0.000452
# mean_score_time                                           0.000384
# std_score_time                                            0.000043
# param_max_depth                                                  5
# param_min_samples_split                                         10
# params                   {'max_depth': 5, 'min_samples_split': 10}
# split0_test_score                                         0.967033
# split1_test_score                                         0.912088
# split2_test_score                                         0.923077
# split3_test_score                                         0.956044
# split4_test_score                                         0.967033
# mean_test_score                                           0.945055
# std_test_score                                            0.023051
# rank_test_score                                                  1
#
#                                                                  1  \
# mean_fit_time                                             0.003275
# std_fit_time                                              0.000148
# mean_score_time                                           0.000316
# std_score_time                                            0.000069
# param_max_depth                                                  5
# param_min_samples_split                                         12
# params                   {'max_depth': 5, 'min_samples_split': 12}
# split0_test_score                                         0.923077
# split1_test_score                                         0.901099
# split2_test_score                                         0.934066
# split3_test_score                                         0.956044
# split4_test_score                                         0.967033
# mean_test_score                                           0.936264
# std_test_score                                            0.023466
# rank_test_score                                                  4
#
#                                                                  2  \
# mean_fit_time                                             0.003198
# std_fit_time                                               0.00013
# mean_score_time                                           0.000269
# std_score_time                                            0.000021
# param_max_depth                                                  5
# param_min_samples_split                                         15
# params                   {'max_depth': 5, 'min_samples_split': 15}
# split0_test_score                                         0.912088
# split1_test_score                                         0.901099
# split2_test_score                                         0.934066
# split3_test_score                                         0.945055
# split4_test_score                                         0.934066
# mean_test_score                                           0.925275
# std_test_score                                             0.01615
# rank_test_score                                                  7
#
#                                                                   3  \
# mean_fit_time                                              0.003244
# std_fit_time                                               0.000149
# mean_score_time                                            0.000291
# std_score_time                                             0.000065
# param_max_depth                                                  10
# param_min_samples_split                                          10
# params                   {'max_depth': 10, 'min_samples_split': 10}
# split0_test_score                                          0.967033
# split1_test_score                                          0.912088
# split2_test_score                                          0.923077
# split3_test_score                                          0.956044
# split4_test_score                                          0.967033
# mean_test_score                                            0.945055
# std_test_score                                             0.023051
# rank_test_score                                                   1
#
#                                                                   4  \
# mean_fit_time                                               0.00323
# std_fit_time                                               0.000151
# mean_score_time                                            0.000282
# std_score_time                                             0.000025
# param_max_depth                                                  10
# param_min_samples_split                                          12
# params                   {'max_depth': 10, 'min_samples_split': 12}
# split0_test_score                                          0.923077
# split1_test_score                                          0.901099
# split2_test_score                                          0.934066
# split3_test_score                                          0.956044
# split4_test_score                                          0.967033
# mean_test_score                                            0.936264
# std_test_score                                             0.023466
# rank_test_score                                                   4
#
#                                                                   5  \
# mean_fit_time                                              0.003239
# std_fit_time                                               0.000175
# mean_score_time                                            0.000278
# std_score_time                                             0.000025
# param_max_depth                                                  10
# param_min_samples_split                                          15
# params                   {'max_depth': 10, 'min_samples_split': 15}
# split0_test_score                                          0.912088
# split1_test_score                                          0.901099
# split2_test_score                                          0.934066
# split3_test_score                                          0.945055
# split4_test_score                                          0.934066
# mean_test_score                                            0.925275
# std_test_score                                              0.01615
# rank_test_score                                                   7
#
#                                                                   6  \
# mean_fit_time                                               0.00332
# std_fit_time                                                0.00026
# mean_score_time                                            0.000284
# std_score_time                                              0.00002
# param_max_depth                                                  15
# param_min_samples_split                                          10
# params                   {'max_depth': 15, 'min_samples_split': 10}
# split0_test_score                                          0.967033
# split1_test_score                                          0.912088
# split2_test_score                                          0.923077
# split3_test_score                                          0.956044
# split4_test_score                                          0.967033
# mean_test_score                                            0.945055
# std_test_score                                             0.023051
# rank_test_score                                                   1
#
#                                                                   7  \
# mean_fit_time                                              0.003236
# std_fit_time                                               0.000115
# mean_score_time                                            0.000296
# std_score_time                                             0.000066
# param_max_depth                                                  15
# param_min_samples_split                                          12
# params                   {'max_depth': 15, 'min_samples_split': 12}
# split0_test_score                                          0.923077
# split1_test_score                                          0.901099
# split2_test_score                                          0.934066
# split3_test_score                                          0.956044
# split4_test_score                                          0.967033
# mean_test_score                                            0.936264
# std_test_score                                             0.023466
# rank_test_score                                                   4
#
#                                                                   8
# mean_fit_time                                              0.003202
# std_fit_time                                               0.000128
# mean_score_time                                            0.000268
# std_score_time                                             0.000016
# param_max_depth                                                  15
# param_min_samples_split                                          15
# params                   {'max_depth': 15, 'min_samples_split': 15}
# split0_test_score                                          0.912088
# split1_test_score                                          0.901099
# split2_test_score                                          0.934066
# split3_test_score                                          0.945055
# split4_test_score                                          0.934066
# mean_test_score                                            0.925275
# std_test_score                                              0.01615
# rank_test_score                                                   7

# %%
tuned_model.best_params_
# Out:
# {'max_depth': 5, 'min_samples_split': 10}

# %%
best_model = tuned_model.best_estimator_

# %%
print(best_model.score(x_train_val, t_train_val))
print(best_model.score(x_test, t_test))
# Out:
# 0.9934065934065934
# 0.956140350877193
